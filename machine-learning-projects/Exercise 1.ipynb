# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('‎Datapreprocessing.csv', header = 2)
df
# Out:
#      1  CountryName CountryCode  Population growth  Total population  \
# 0    2       Brazil         BRA           0.817556      2.076529e+08
# 1    3  Switzerland         CHE           1.077221      8.372098e+06
# 2    4      Germany         DEU           1.193867      8.266768e+07
# 3    5      Denmark         DNK           0.834638               NaN
# 4    6        Spain         ESP          -0.008048      4.644396e+07
# 5    7       France         FRA           0.407491      6.689611e+07
# 6    8        Japan         JPN          -0.115284      1.269945e+08
# 7    9       Greece         GRC          -0.687543      1.074674e+07
# 8   10         Iran         IRN           1.148789      8.027743e+07
# 9   11       Kuwait         KWT           2.924206      4.052584e+06
# 10  12      Morocco         MAR                NaN      3.527679e+07
# 11  13      Nigeria         NGA           2.619034      1.859896e+08
# 12  14        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
df.drop(labels = '1',axis = 1 ,inplace = True)
df
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638               NaN
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR                NaN      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %% [markdown]
# # Missing Values

# %%
df.dropna()
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# 14        India         IND           1.148215      1.324171e+09
#
#     Area (sq. km) International Visitors  Coronavirus Cases
# 0       8358140.0                      B              59324
# 1         39516.0                      B              29061
# ...

# %%
df.dropna(axis = 1)
# Out:
#     CountryName CountryCode International Visitors  Coronavirus Cases
# 0        Brazil         BRA                      B              59324
# 1   Switzerland         CHE                      B              29061
# 2       Germany         DEU                      A             156727
# 3       Denmark         DNK                      B               8575
# 4         Spain         ESP                      A             223759
# 5        France         FRA                      A             161488
# 6         Japan         JPN                      B              13231
# 7        Greece         GRC                      C               2506
# 8          Iran         IRN                      D              90481
# 9        Kuwait         KWT                      C               3075
# 10      Morocco         MAR                      C               4047
# 11      Nigeria         NGA                      D               1182
# ...

# %%
df.fillna(method = 'bfill')
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      4.644396e+07
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           2.619034      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
df.isnull().sum()
# Out:
#  CountryName              0
# CountryCode               0
# Population growth         2
# Total population          1
# Area (sq. km)             1
# International Visitors    0
# Coronavirus Cases         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer1 = SimpleImputer()
df1 =df.copy()
df1.iloc[:,2:5] = imputer1.fit_transform(df.iloc[:,2:5])
df1
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      1.565725e+08
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           1.142708      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
imputer2 = SimpleImputer(strategy = 'median')
df2 =df.copy()
df2.iloc[:,2:5] = imputer2.fit_transform(df.iloc[:,2:5])
df2
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      5.667003e+07
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           1.077221      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
imputer3 = SimpleImputer(strategy = 'constant',fill_value = 5800000)
df3 =df.copy()
df3.iloc[:,3:4] = imputer3.fit_transform(df.iloc[:,3:4])
df3
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      5.800000e+06
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR                NaN      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
from sklearn.impute import KNNImputer

# %%
imputer4 = KNNImputer(n_neighbors=2)
df4 =df.copy()
df4.iloc[:,2:5] = imputer4.fit_transform(df.iloc[:,2:5])
df4
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      6.212341e+06
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           0.413295      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %% [markdown]
# # Categorial Variables

# %%
df5 = pd.get_dummies(df4,columns = df4.columns[5:6])
df5
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      6.212341e+06
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           0.413295      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
df5.drop(['International Visitors_D'],axis = 1, inplace = True)
df5
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      6.212341e+06
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           0.413295      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %% [markdown]
# # Feature Scailing

# %%
df6 = df5.copy()
df6.drop([' CountryName', 'CountryCode'], axis = 1 , inplace = True)

# %%
df6
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0            0.817556      2.076529e+08      8358140.0              59324
# 1            1.077221      8.372098e+06        39516.0              29061
# 2            1.193867      8.266768e+07       348900.0             156727
# 3            0.834638      6.212341e+06        42262.0               8575
# 4           -0.008048      4.644396e+07       500210.0             223759
# 5            0.407491      6.689611e+07       547557.0             161488
# 6           -0.115284      1.269945e+08       364560.0              13231
# 7           -0.687543      1.074674e+07       128900.0               2506
# 8            1.148789      8.027743e+07      1628760.0              90481
# 9            2.924206      4.052584e+06        26936.0               3075
# 10           0.413295      3.527679e+07       446300.0               4047
# 11           2.619034      1.859896e+08       910770.0               1182
# ...

# %%
from sklearn.preprocessing import MinMaxScaler ,Normalizer, StandardScaler

# %%
T1 = MinMaxScaler()
MinMaxDF = pd.DataFrame(T1.fit_transform(df6),columns =df6.columns)
MinMaxDF
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0            0.359846          0.155178       1.000000           0.261222
# 1            0.421929          0.004390       0.003343           0.125256
# 2            0.449817          0.060607       0.040411           0.698837
# 3            0.363930          0.002756       0.003672           0.033215
# 4            0.162457          0.033198       0.058539           1.000000
# 5            0.261806          0.048673       0.064212           0.720227
# 6            0.136818          0.094147       0.042287           0.054134
# 7            0.000000          0.006187       0.014053           0.005949
# 8            0.439039          0.058798       0.193751           0.401205
# 9            0.863515          0.001122       0.001836           0.008505
# 10           0.263194          0.024748       0.052080           0.012872
# 11           0.790553          0.138786       0.107729           0.000000
# ...

# %%
T2 = Normalizer()
NormalDf = pd.DataFrame(T2.fit_transform(df6),columns = df6.columns)
NormalDf
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0        3.933941e-09          0.999191       0.040218           0.000285
# 1        1.286658e-07          0.999983       0.004720           0.003471
# 2        1.444160e-08          0.999989       0.004220           0.001896
# 3        1.343483e-07          0.999976       0.006803           0.001380
# 4       -1.732739e-10          0.999930       0.010769           0.004817
# 5        6.091179e-09          0.999964       0.008185           0.002414
# 6       -9.077849e-10          0.999996       0.002871           0.000104
# 7       -6.397224e-08          0.999928       0.011993           0.000233
# 8        1.430728e-08          0.999794       0.020285           0.001127
# 9        7.215497e-07          0.999978       0.006646           0.000759
# 10       1.171483e-08          0.999920       0.012650           0.000115
# 11       1.408144e-08          0.999988       0.004897           0.000006
# ...

# %%
T3 = StandardScaler()
StandardDf = pd.DataFrame(T3.fit_transform(df6),columns = df6.columns)
StandardDf
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0           -0.180705          0.190294       3.487210           0.078032
# 1            0.047911         -0.430316      -0.518157          -0.361669
# 2            0.150608         -0.198941      -0.369191           1.493232
# 3           -0.165666         -0.437042      -0.516835          -0.659316
# 4           -0.907588         -0.311750      -0.296336           2.467161
# 5           -0.541737         -0.248057      -0.273539           1.562406
# 6           -1.002001         -0.060896      -0.361651          -0.591668
# 7           -1.505832         -0.422920      -0.475120          -0.747495
# 8            0.110920         -0.206385       0.247054           0.530722
# 9            1.674043         -0.443768      -0.524215          -0.739228
# 10          -0.536627         -0.346528      -0.322293          -0.725105
# 11           1.405361          0.122830      -0.098654          -0.766732
# ...

# %% [markdown]
# # Outlier

# %%
df4
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      6.212341e+06
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           0.413295      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %% [markdown]
# ## 1. z-score

# %%
labels = ['Population growth','Total population','Area (sq. km)','Coronavirus Cases']

# %%
from scipy import stats
z=np.abs(stats.zscore(df4[labels]))
z
# Out:
# array([[0.18070538, 0.19029435, 3.48720963, 0.07803214],
#        [0.04791069, 0.43031573, 0.5181575 , 0.36166872],
#        [0.15060843, 0.19894071, 0.36919098, 1.49323166],
#        [0.16566604, 0.43704175, 0.51683532, 0.6593164 ],
#        [0.90758795, 0.31175044, 0.29633613, 2.46716114],
#        [0.54173675, 0.24805734, 0.27353883, 1.56240576],
#        [1.00200133, 0.06089591, 0.36165078, 0.59166788],
#        [1.50583215, 0.4229205 , 0.47511964, 0.74749485],
#        [0.11092047, 0.20638457, 0.24705387, 0.53072222],
#        [1.67404325, 0.44376777, 0.52421469, 0.73922767],
#        [0.536627  , 0.34652781, 0.32229346, 0.72510517],
#        [1.40536148, 0.12282966, 0.09865397, 0.76673167],
#        [2.17664619, 0.44838552, 0.53159407, 0.6344422 ],
#        [0.8357491 , 0.42554774, 0.34106691, 0.51307878],
#        [0.11041519, 3.66741178, 0.89438878, 0.39281958]])

# %%
print(np.where(z>3))
# Out:
# (array([ 0, 14], dtype=int64), array([2, 1], dtype=int64))

# %%
z[0][2]
# Out:
# 3.487209629108636

# %%
z[14][1]
# Out:
# 3.6674117803334836

# %% [markdown]
# ## 2. IQR score

# %%
Q1=df4[labels].quantile(0.25)
Q1
# Out:
# Population growth    2.405193e-01
# Total population     9.137610e+06
# Area (sq. km)        8.558100e+04
# Coronavirus Cases    6.311000e+03
# Name: 0.25, dtype: float64

# %%
Q3=df4[labels].quantile(0.75)
Q3
# Out:
# Population growth    1.171328e+00
# Total population     1.048311e+08
# Area (sq. km)        7.291635e+05
# Coronavirus Cases    7.490250e+04
# Name: 0.75, dtype: float64

# %%
IQR=Q3-Q1
IQR
# Out:
# Population growth    9.308084e-01
# Total population     9.569349e+07
# Area (sq. km)        6.435825e+05
# Coronavirus Cases    6.859150e+04
# dtype: float64

# %%
(df4[labels]<Q1-1.5*IQR) | (df4[labels]>Q3+1.5*IQR)
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases
# 0               False             False           True              False
# 1               False             False          False              False
# 2               False             False          False              False
# 3               False             False          False              False
# 4               False             False          False               True
# 5               False             False          False              False
# 6               False             False          False              False
# 7               False             False          False              False
# 8               False             False          False              False
# 9                True             False          False              False
# 10              False             False          False              False
# 11               True             False          False              False
# ...

# %% [markdown]
# ## Removing outliers

# %%
df4.shape
# Out:
# (15, 7)

# %%
df7 = df4[(z<3).all(axis=1)]
df7.shape
# Out:
# (13, 7)

# %%
df8 = df4[((df4[labels]>=Q1-1.5*IQR) & (df4[labels]<=Q3+1.5*IQR)).all(axis=1)]
df8.shape
# Out:
# (9, 7)

# %%
df8
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 1   Switzerland         CHE           1.077221         8372098.0
# 2       Germany         DEU           1.193867        82667685.0
# 3       Denmark         DNK           0.834638         6212341.0
# 5        France         FRA           0.407491        66896109.0
# 6         Japan         JPN          -0.115284       126994511.0
# 7        Greece         GRC          -0.687543        10746740.0
# 8          Iran         IRN           1.148789        80277428.0
# 10      Morocco         MAR           0.413295        35276786.0
# 13       Sweden         SWE           0.073548         9903122.0
#
#     Area (sq. km) International Visitors  Coronavirus Cases
# 1         39516.0                      B              29061
# 2        348900.0                      A             156727
# 3         42262.0                      B               8575
# 5        547557.0                      A             161488
# ...

# %%
df7
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 1   Switzerland         CHE           1.077221         8372098.0
# 2       Germany         DEU           1.193867        82667685.0
# 3       Denmark         DNK           0.834638         6212341.0
# 4         Spain         ESP          -0.008048        46443959.0
# 5        France         FRA           0.407491        66896109.0
# 6         Japan         JPN          -0.115284       126994511.0
# 7        Greece         GRC          -0.687543        10746740.0
# 8          Iran         IRN           1.148789        80277428.0
# 9        Kuwait         KWT           2.924206         4052584.0
# 10      Morocco         MAR           0.413295        35276786.0
# 11      Nigeria         NGA           2.619034       185989640.0
# 12        Qatar         QAT           3.495070         2569804.0
# 13       Sweden         SWE           0.073548         9903122.0
#
# ...

# %% [markdown]
# ## To remove or not to remove...!?

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # With ouliers removed

# %%
df9 = df6.copy()
df9.drop([0,14], inplace = True)
StanDf = pd.DataFrame(T3.fit_transform(df9),columns = df9.columns)
StanDf
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0            0.039629         -0.792675      -0.870569          -0.361267
# 1            0.135379          0.580436      -0.154515           1.375305
# 2           -0.159501         -0.832591      -0.864214          -0.639927
# 3           -0.851236         -0.089041       0.195685           2.287105
# 4           -0.510133          0.288950       0.305267           1.440066
# 5           -0.939263          1.399673      -0.118270          -0.576594
# 6           -1.409013         -0.748788      -0.663694          -0.722480
# 7            0.098376          0.536260       2.807660           0.474196
# 8            1.555763         -0.872507      -0.899685          -0.714740
# 9           -0.505369         -0.295430       0.070913          -0.701519
# 10           1.305256          2.490005       1.145907          -0.740490
# 11           2.024368         -0.899912      -0.935156          -0.616639
# ...

# %%
x = StanDf.copy()
x.drop(labels = ['Coronavirus Cases'], axis = 1 , inplace = True)

# %%
x
# Out:
#     Population growth  Total population  Area (sq. km)  \
# 0            0.039629         -0.792675      -0.870569
# 1            0.135379          0.580436      -0.154515
# 2           -0.159501         -0.832591      -0.864214
# 3           -0.851236         -0.089041       0.195685
# 4           -0.510133          0.288950       0.305267
# 5           -0.939263          1.399673      -0.118270
# 6           -1.409013         -0.748788      -0.663694
# 7            0.098376          0.536260       2.807660
# 8            1.555763         -0.872507      -0.899685
# 9           -0.505369         -0.295430       0.070913
# 10           1.305256          2.490005       1.145907
# 11           2.024368         -0.899912      -0.935156
# 12          -0.784257         -0.764379      -0.019328
#
#     International Visitors_A  International Visitors_B  \
# 0                  -0.547723                  1.500000
# 1                   1.825742                 -0.666667
# ...

# %%
y = StanDf['Coronavirus Cases'].copy()
y
# Out:
# 0    -0.361267
# 1     1.375305
# 2    -0.639927
# 3     2.287105
# 4     1.440066
# 5    -0.576594
# 6    -0.722480
# 7     0.474196
# 8    -0.714740
# 9    -0.701519
# 10   -0.740490
# 11   -0.616639
# 12   -0.503018
# Name: Coronavirus Cases, dtype: float64

# %%
lm = LinearRegression()
lm.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# 1.4789718814100265e-18

# %%
lm.coef_
# Out:
# array([-0.05761907, -0.26189763,  0.35634901,  0.88693082,  0.01885255,
#        -0.14626916])

# %%
coef_df=pd.DataFrame(lm.coef_,x.columns,columns=['Coefficient'])
coef_df
# Out:
#                           Coefficient
# Population growth           -0.057619
# Total population            -0.261898
# Area (sq. km)                0.356349
# International Visitors_A     0.886931
# International Visitors_B     0.018853
# International Visitors_C    -0.146269

# %%
prediction = lm.predict(x)

# %%
import matplotlib.pyplot as plt
plt.scatter(y,prediction)

# %%
from sklearn import metrics

# %%
print('MSE:', metrics.mean_squared_error(y,prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y,prediction)))
# Out:
# MSE: 0.03355681506181373
# RMSE: 0.18318519334764405

# %% [markdown]
# ## without outliers removed

# %%
x1 = StandardDf.copy()
x1.drop(labels = ['Coronavirus Cases'], axis = 1 , inplace = True)

# %%
x1
# Out:
#     Population growth  Total population  Area (sq. km)  \
# 0           -0.180705          0.190294       3.487210
# 1            0.047911         -0.430316      -0.518157
# 2            0.150608         -0.198941      -0.369191
# 3           -0.165666         -0.437042      -0.516835
# 4           -0.907588         -0.311750      -0.296336
# 5           -0.541737         -0.248057      -0.273539
# 6           -1.002001         -0.060896      -0.361651
# 7           -1.505832         -0.422920      -0.475120
# 8            0.110920         -0.206385       0.247054
# 9            1.674043         -0.443768      -0.524215
# 10          -0.536627         -0.346528      -0.322293
# 11           1.405361          0.122830      -0.098654
# 12           2.176646         -0.448386      -0.531594
# 13          -0.835749         -0.425548      -0.341067
# 14           0.110415          3.667412       0.894389
#
#     International Visitors_A  International Visitors_B  \
# ...

# %%
y1 = StandardDf['Coronavirus Cases'].copy()
y1
# Out:
# 0     0.078032
# 1    -0.361669
# 2     1.493232
# 3    -0.659316
# 4     2.467161
# 5     1.562406
# 6    -0.591668
# 7    -0.747495
# 8     0.530722
# 9    -0.739228
# 10   -0.725105
# 11   -0.766732
# 12   -0.634442
# 13   -0.513079
# 14   -0.392820
# Name: Coronavirus Cases, dtype: float64

# %%
lm1 = LinearRegression()
lm1.fit(x1,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm1.intercept_
# Out:
# -4.7610505955918485e-17

# %%
lm1.coef_
# Out:
# array([-0.11118312, -0.0431673 ,  0.17124588,  0.75348368, -0.20215506,
#        -0.2710691 ])

# %%
prediction1 = lm1.predict(x1)

# %%
print('MSE:', metrics.mean_squared_error(y1,prediction1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y1,prediction1)))
# Out:
# MSE: 0.0846328577377525
# RMSE: 0.29091726957633934

# %% [markdown]
# # Statsmodel

# %%
import statsmodels.formula.api as smf

# %%
lm2 = smf.ols(formula = 'Q("Coronavirus Cases") ~ Q("Population growth") + Q("Total population") + Q("Area (sq. km)") + Q("International Visitors_A") + Q("International Visitors_B") + Q("International Visitors_C")', data = StanDf).fit()

# %%
lm2.summary()
# Out:
# E:\Ana\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Q("Coronavirus Cases")   R-squared:                       0.966
# Model:                                OLS   Adj. R-squared:                  0.933
# Method:                     Least Squares   F-statistic:                     28.80
# Date:                    Sat, 13 Jun 2020   Prob (F-statistic):           0.000359
# Time:                            22:59:58   Log-Likelihood:                 3.6181
# No. Observations:                      13   AIC:                             6.764
# Df Residuals:                           6   BIC:                             10.72
# Df Model:                               6
# Covariance Type:                nonrobust
# ...

# %% [markdown]
# # Polynomial Regression

# %%
StanDf
# Out:
#     Population growth  Total population  Area (sq. km)  Coronavirus Cases  \
# 0            0.039629         -0.792675      -0.870569          -0.361267
# 1            0.135379          0.580436      -0.154515           1.375305
# 2           -0.159501         -0.832591      -0.864214          -0.639927
# 3           -0.851236         -0.089041       0.195685           2.287105
# 4           -0.510133          0.288950       0.305267           1.440066
# 5           -0.939263          1.399673      -0.118270          -0.576594
# 6           -1.409013         -0.748788      -0.663694          -0.722480
# 7            0.098376          0.536260       2.807660           0.474196
# 8            1.555763         -0.872507      -0.899685          -0.714740
# 9           -0.505369         -0.295430       0.070913          -0.701519
# 10           1.305256          2.490005       1.145907          -0.740490
# 11           2.024368         -0.899912      -0.935156          -0.616639
# ...

# %%
x2 = StanDf.iloc[:, 1:2].copy()
x2
# Out:
#     Total population
# 0          -0.792675
# 1           0.580436
# 2          -0.832591
# 3          -0.089041
# 4           0.288950
# 5           1.399673
# 6          -0.748788
# 7           0.536260
# 8          -0.872507
# 9          -0.295430
# 10          2.490005
# 11         -0.899912
# 12         -0.764379

# %%
y2 = StanDf.iloc[:,3:4].copy()
y2
# Out:
#     Coronavirus Cases
# 0           -0.361267
# 1            1.375305
# 2           -0.639927
# 3            2.287105
# 4            1.440066
# 5           -0.576594
# 6           -0.722480
# 7            0.474196
# 8           -0.714740
# 9           -0.701519
# 10          -0.740490
# 11          -0.616639
# 12          -0.503018

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 2)
x_poly = poly.fit_transform(x2)

# %%
lm3 = LinearRegression()
lm3.fit(x_poly,y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm3.coef_
# Out:
# array([[ 0.        ,  0.8995388 , -0.65486117]])

# %%
lm3.intercept_
# Out:
# array([0.65486117])
